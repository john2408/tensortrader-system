# %%
import pandas as pd
import numpy as np
import datetime

from xgboost import XGBClassifier

from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.utils import class_weight
from sklearn.model_selection import GridSearchCV

from os.path import join
from os import getcwd
from pathlib import Path
from sys import path

full_path = getcwd()
functions_path = join( Path(full_path).parents[0].parents[0] )
path.append( functions_path  )

import mlflow
import dateutil

from joblib import parallel_backend


from functions import utils, modelling
import tempfile
import os

#Hyperparameter Optimization
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

# %%
# Load data
feature_config = 14
strategy = '1-1_vb_15m' #'t20-r10_w15'
file_path = "/mnt/d/Tensor_Database/01_Cryptos/Features_Eng/Feature_Engineering_conf_1_Tickers_4_Stategy_1-1_vb_15m.parquet"

input_file_path = os.path.join( file_path)
df = pd.read_parquet(input_file_path)

# %%
def generate_labels():

    # The time window for the features - N
    feature_window = 60
    # The time window for the labels (also called horizon) - M
    label_window = 5

    # Calculate daily returns on the adjusted close
    df['daily_returns'] = df['Close'].pct_change()
    # Calculate the threshold dynamically from the daily returns on a rolling basis on the feature_window
    # The threshold is a function of the rolling standard deviation
    df['return_threshold'] = 0.125 * \
        np.sqrt(feature_window)*df.daily_returns.rolling(feature_window).std()
    
    
    df['return_threshold'] = df.daily_returns.ewm(span = feature_window).std()
    
    # Calculate the future return from current price to the end of the label window
    df['fut_returns'] = df['Close'].pct_change(
        +label_window).shift(-label_window)
    # Assign class label to the feature window based on the returns of the label window compared to a dynamic threshold
    df['target_class'] = np.where(df.fut_returns > df.return_threshold, 1, np.where(
        df.fut_returns < -df.return_threshold, -1, 0))

# %%
df.loc[:,'sma_signal'] = df['sma_cross_over'].apply(lambda x: 1 if x == 1 else 0)

# %%
def feature_selection(df: pd.DataFrame, 
                    X_columns: list, 
                    start_train_date : datetime.datetime,
                    end_train_date : datetime.datetime,
                    forecast_variable : str ):
    """ Feature Selection Cases

    Args: 
        df (pandas.DataFrame): Input data frame containg target variable and features
        case (int): if target is entry_type, select among different features scenarios
        train_start_date (datetime.datetime): start training date
    """
    
    
    df = df.dropna().copy()

    # Create Dummy Columns for Tickers
    X_columns += list(df['Ticker'].unique())
    df = df.drop(columns = ['Ticker']).join(pd.get_dummies(df['Ticker']))

    X_train = (df.loc[(df['Date'] >= start_train_date) 
                    & (df['Date'] < end_train_date),:]
                    .filter(X_columns)
                    .reset_index(drop = True))

    X_test = (df.loc[(df['Date'] >= end_train_date),:]
                .filter(X_columns).reset_index(drop = True))

    Y_train = np.squeeze((df.loc[(df['Date'] >= start_train_date) 
                    & (df['Date'] < end_train_date),:]
                    .filter([forecast_variable])
                    .astype(int)))

    Y_test = np.squeeze(df.loc[(df['Date'] >= end_train_date),:]
                .filter([forecast_variable])
                .reset_index(drop = True)
                .astype(int))

    # X_train.drop(columns = ['Date'], inplace = True)
    # X_test.drop(columns = ['Date'], inplace = True)

    X_train.set_index(['Date'], inplace = True)
    X_test.set_index(['Date'], inplace = True)

    dfs = [X_train, X_test, Y_train, Y_test]

    return dfs

# %%
X_columns = ['Ticker', 'Date', 
                'Volume_standard','Number of Trades_standard', 'max_trades_standard',
                'month', 'day', 'hour', 'minute', 
                'Close_lag_1', 'Close_lag_3', 'Close_lag_5', 'Close_lag_15',
                'Close_lag_30', 'VWMA_60', 'VWMA_15', 'Volume_sma_5', 'Volume_sma_30', 'Volume_std_5',
                'Volume_std_30','ATRr_15', 'PDIST','BBU_15_2.0', 'BBB_15_2.0', 'BBP_15_2.0', 'BBL_120_2.0', 'BBM_120_2.0',
                'BBU_120_2.0', 'BBB_120_2.0', 'BBP_120_2.0', 'MACD_15_120_9',
                'MACDh_15_120_9', 'MACDs_15_120_9','sma_signal'] 


forecast_variable = 'metalabel'

end_train_date = datetime.datetime(2022, 1, 31) 
start_train_date = end_train_date  - dateutil.relativedelta.relativedelta(months = 6)

# ---------------------------------------------- #
# (1) Feature Selection - Train/Test Split
# ---------------------------------------------- # 

X_train, X_test, Y_train, Y_test = feature_selection(df.copy(),
                                                     X_columns, 
                                                     start_train_date,
                                                     end_train_date,
                                                     forecast_variable)


# ---------------------------------------------- #
# (2) Synthetic Minority Oversampling Technique
# ---------------------------------------------- # 
from imblearn.over_sampling import SMOTE

# Ref: https://arxiv.org/pdf/1106.1813.pdf
sm = SMOTE()

X_train_res, y_train_res = sm.fit_resample(X_train, Y_train)

# %%
labels, counts = np.unique(y_train_res, return_counts=True)

# %%
print("Labels are: ", labels )
print("Counts are: ", counts )
# Out:
# Labels are:  [0 1]
# Counts are:  [765280 765280]

# %%
60*24
# Out:
# 1440

# %%
test_size = 20000
n_splits = 10
max_train_size = None
gap=30

# Create Temporal Cross Validation Object
tscv = TimeSeriesSplit(n_splits = n_splits, 
                      max_train_size  = max_train_size, 
                      test_size = test_size, 
                      gap = gap)

param_grid = {
              'learning_rate': Real(0.005, 0.05, prior='log-uniform'),
              'max_depth': Integer(3, 25, prior='log-uniform'),
              'n_estimators': Integer(10, 100, prior='log-uniform'),
            #   'gamma': Real(0.1, 0.3, prior='log-uniform'),
            #   'reg_alpha': Real(0.01, 1.6, prior='log-uniform'),
            #   'reg_lambda': Real(0.01, 1.6, prior='log-uniform'),
            #   'min_child_weight': Real(0.01, 5, prior='log-uniform'),
            #   'max_delta_step' : Real(0.01, 5, prior='log-uniform')
               }

# ---------------------------------------------- #
# Experiment Parameters 
# ---------------------------------------------- #
n_jobs = 4
n_iter = 10
random_state = 123
experiment_name = f'TBM-{strategy}' 
experiment_data_folder = 'experiment_data'
model_name = 'XGboost SMA Cross + XGBoost'


for train_index, test_index in tscv.split(X_train):
     print("TRAIN:", train_index, "TEST:", test_index)


xgb_model = XGBClassifier(objective="binary:logistic", 
                            booster='gbtree',
                            eval_metric='auc',
                            tree_method='hist', 
                            grow_policy='lossguide',
                            use_label_encoder=False)
                            
# xgb_model = XGBClassifier(objective="binary:logistic", 
#                             booster='gbtree',
#                             eval_metric='auc',
#                             tree_method='gpu_hist',
#                             gpu_id=0,
#                             grow_policy='lossguide',
#                             use_label_encoder=False)
# Bayesian Grid Search
bayes_search = BayesSearchCV(
    xgb_model,
    param_grid,
    n_iter = n_iter,
    random_state = random_state,
    n_jobs = n_jobs,
    cv = tscv
)

# executes bayesian optimization
model = bayes_search.fit(X_train, Y_train)

# Predict training set
Y_pred = model.predict(X_test)

#print(Y_pred)

# Evaluate Predictions
conf_matrix = confusion_matrix(Y_test, Y_pred)/len(Y_pred)
class_accuracy = utils.cal_label_accuracy(conf_matrix)

print(class_accuracy)
# Out:
# TRAIN: [     0      1      2 ... 570631 570632 570633] TEST: [570664 570665 570666 ... 590661 590662 590663]
# TRAIN: [     0      1      2 ... 590631 590632 590633] TEST: [590664 590665 590666 ... 610661 610662 610663]
# TRAIN: [     0      1      2 ... 610631 610632 610633] TEST: [610664 610665 610666 ... 630661 630662 630663]
# TRAIN: [     0      1      2 ... 630631 630632 630633] TEST: [630664 630665 630666 ... 650661 650662 650663]
# TRAIN: [     0      1      2 ... 650631 650632 650633] TEST: [650664 650665 650666 ... 670661 670662 670663]
# TRAIN: [     0      1      2 ... 670631 670632 670633] TEST: [670664 670665 670666 ... 690661 690662 690663]
# TRAIN: [     0      1      2 ... 690631 690632 690633] TEST: [690664 690665 690666 ... 710661 710662 710663]
# TRAIN: [     0      1      2 ... 710631 710632 710633] TEST: [710664 710665 710666 ... 730661 730662 730663]
# TRAIN: [     0      1      2 ... 730631 730632 730633] TEST: [730664 730665 730666 ... 750661 750662 750663]
# TRAIN: [     0      1      2 ... 750631 750632 750633] TEST: [750664 750665 750666 ... 770661 770662 770663]
# {'class_0': 100.0, 'class_1': 0.0}

# %%
Importance = model.best_estimator_.feature_importances_
df_importance = pd.DataFrame({'Variable': X_columns, 'Importance':Importance})
df_importance.sort_values(by = ['Importance'], ascending = False, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_236/2520875992.py in <module>
#       1 Importance = model.best_estimator_.feature_importances_
# ----> 2 df_importance = pd.DataFrame({'Variable': X_columns, 'Importance':Importance})
#       3 df_importance.sort_values(by = ['Importance'], ascending = False, inplace = True)
#
# ~/anaconda3/envs/Tensor/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/envs/Tensor/lib/python3.7/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     463
#     464     return arrays_to_mgr(
# --> 465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#     467
#
# ~/anaconda3/envs/Tensor/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# ~/anaconda3/envs/Tensor/lib/python3.7/site-packages/pandas/core/internals/construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
t, l = np.unique(Y_test, return_counts=True)

# %%
t, l
# Out:
# (array([0, 1]), array([306707,   2173]))

# %%
add_params = { 'feature_config' : feature_config,
                'forecast_variable': forecast_variable,
                'end_train_date': end_train_date,
                'start_train_date': start_train_date
                }

# Store Experiment in MLFlow
print("Storing Model Results...")
modelling.log_results(gridsearch =  model, 
                class_accuracy = class_accuracy, 
                add_params = add_params,
                training_columns = X_columns,
                experiment_name = experiment_name, 
                experiment_data_folder = experiment_data_folder, 
                model_name = model_name, 
                tags={}, 
                log_only_best=True)
# Out:
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_236/234530545.py in <module>
#      15                 model_name = model_name,
#      16                 tags={},
# ---> 17                 log_only_best=True)
#
# /mnt/d/Tensor/tensortrader/tensortrader/notebooks/functions/modelling.py in log_results(gridsearch, class_accuracy, add_params, training_columns, experiment_name, experiment_data_folder, model_name, tags, log_only_best)
#     357                         conda_env,
#     358                         tags,
# --> 359                         log_only_best)
#     360     else:
#     361         for run_index in range(len(gridsearch.cv_results_['params'])):
#
# /mnt/d/Tensor/tensortrader/tensortrader/notebooks/functions/modelling.py in log_run(gridsearch, class_accuracy, add_params, training_columns, model_name, run_index, experiment_data_folder, conda_env, tags, log_only_best)
#     286
#     287         Importance = gridsearch.best_estimator_.feature_importances_
# --> 288         df_importance = pd.DataFrame({'Variable': training_columns, 'Importance':Importance})
#     289         df_importance.sort_values(by = ['Importance'], ascending = False, inplace = True)
#     290         df_importance.to_csv(importance_path, index=False)
#
# ~/anaconda3/envs/Tensor/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/envs/Tensor/lib/python3.7/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     463
#     464     return arrays_to_mgr(
# --> 465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#     467
#
# ~/anaconda3/envs/Tensor/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# ~/anaconda3/envs/Tensor/lib/python3.7/site-packages/pandas/core/internals/construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
# param_grid = {
#               'learning_rate': Real(0.005, 0.05, prior='log-uniform'),
#               'max_depth': Integer(3, 25, prior='log-uniform'),
#               'n_estimators': Integer(10, 100, prior='log-uniform'),
#             #   'gamma': Real(0.1, 0.3, prior='log-uniform'),
#             #   'reg_alpha': Real(0.01, 1.6, prior='log-uniform'),
#             #   'reg_lambda': Real(0.01, 1.6, prior='log-uniform'),
#             #   'min_child_weight': Real(0.01, 5, prior='log-uniform'),
#             #   'max_delta_step' : Real(0.01, 5, prior='log-uniform')
#                }

# # ---------------------------------------------- #
# # Experiment Parameters 
# # ---------------------------------------------- #
# n_jobs = -2
# n_iter = 35
# random_state = 123
# experiment_name = f'EntryType-BayesianCV-Feat14-Classweight2-60-{strategy}' 
# experiment_data_folder = 'experiment_data'
# model_name = 'Risk-Profit Trading Classification'


# # ---------------------------------------------- #
# # Outer CV Parameters 
# # ---------------------------------------------- #
# forecast_variable = 'entry_type' # risk_type , entry_type or return_5m_target
# case = 4
# n_splits = 60
# test_period_length = 60
# train_period_length = 5000 
# lookahead = 1
# n_points_w = 480

# # ---------------------------------------------- #
# # Inner CV Parameters 
# # ---------------------------------------------- #
# test_period_length_cv = 30
# n_splits_cv = 4

# # 11 Monate - Training (CV Time Series)
# # 1 Monat - Test (Retraining Zeitraum)

# cv_bayesian_search = modelling.MultipleTimeSeriesCV(n_splits = n_splits,
#                                 train_period_length = train_period_length, 
#                                 test_period_length = test_period_length, 
#                                 lookahead = lookahead, 
#                                 date_idx = 'datetime'
#                                 )


# train_start_date = None
# max_test_date = datetime.datetime(2021, 10, 14)

# df_model = df.set_index(['ticker', 'datetime']).copy(deep = True)

# test_days = []

# # modelling.check_test_training_indeces(cv_bayesian_search, df_model)

# for train_idx, test_idx in cv_bayesian_search.split(df_model):

#     print("Testing for", f"{min(train_idx)}-{max(train_idx)}:{min(test_idx)}-{max(test_idx)}")
    
#     dfs = feature_selection(df, 
#                             case, 
#                             train_start_date ,
#                             max_test_date,
#                             train_idx , 
#                             test_idx , 
#                             forecast_variable)

    

#     print(" Running Model...")

#     # # Optimize Model and test
#     model, class_accuracy, X_columns, classes_weights = bayesian_gridcv_xgb_model(dfs,
#                                                               forecast_variable ,
#                                                               param_grid,
#                                                               n_jobs,
#                                                               n_iter,
#                                                               random_state,
#                                                               test_period_length_cv,                        
#                                                               n_splits_cv,
#                                                               n_points_w,
#                                                                 )

#     print(class_accuracy)

#     Y_train = dfs[3]
    
#     add_params = { 'feature_config' : feature_config,
#                     'forecast_variable': forecast_variable,
#                     'train_period_length':train_period_length,
#                     'test_period_length':test_period_length,
#                     'counts_0': Y_train[Y_train[forecast_variable] == 0].shape[0],
#                     'counts_1': Y_train[Y_train[forecast_variable] == 1].shape[0],
#                     'test_period_length_cv':test_period_length_cv,
#                     'n_splits_cv': n_splits_cv,
#                     'case':case,
#                     'n_last_values_weight_class': n_points_w

#                     }

#     # Store Experiment in MLFlow
#     print("Storing Model Results...")
#     modelling.log_results(gridsearch =  model, 
#                     class_accuracy = class_accuracy, 
#                     add_params = add_params,
#                     training_columns = X_columns,
#                     experiment_name = experiment_name, 
#                     experiment_data_folder = experiment_data_folder, 
#                     model_name = model_name, 
#                     tags={}, 
#                     log_only_best=True)
# Out:
# Testing for 32371-37370:37371-37430
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2940
# 1.0    2060
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 98.21, 'class_1': 0.0}
# {'class_0': 98.21, 'class_1': 0.0}
# Storing Model Results...
# INFO: 'EntryType-BayesianCV-Feat14-Classweight2-60-t10-r10_w5' does not exist. Creating a new experiment
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/0e4e77515abd40b8b74c12da4f6d2bc1/artifacts
# runID: 0e4e77515abd40b8b74c12da4f6d2bc1
# Testing for 32311-37310:37311-37370
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2915
# 1.0    2085
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 100.0, 'class_1': 0.0}
# {'class_0': 100.0, 'class_1': 0.0}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/7d493322358e488ba9fa991be5838fbf/artifacts
# runID: 7d493322358e488ba9fa991be5838fbf
# Testing for 32251-37250:37251-37310
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2900
# 1.0    2100
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 100.0, 'class_1': 0.0}
# {'class_0': 100.0, 'class_1': 0.0}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/1cd71f4c544c4970b7c638957ad8f6b6/artifacts
# runID: 1cd71f4c544c4970b7c638957ad8f6b6
# Testing for 32191-37190:37191-37250
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2887
# 1.0    2113
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 100.0, 'class_1': 0.0}
# {'class_0': 100.0, 'class_1': 0.0}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/2a608a7ba0ac479c8dd3fb6ed123e55e/artifacts
# runID: 2a608a7ba0ac479c8dd3fb6ed123e55e
# Testing for 32131-37130:37131-37190
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2886
# 1.0    2114
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 100.0, 'class_1': 0.0}
# {'class_0': 100.0, 'class_1': 0.0}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/3f820aecb3304048aabffe186e4bac8b/artifacts
# runID: 3f820aecb3304048aabffe186e4bac8b
# Testing for 32071-37070:37071-37130
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2890
# 1.0    2110
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 41.67, 'class_1': 87.5}
# {'class_0': 41.67, 'class_1': 87.5}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/4734d20d861e4c009dc8864d6e556bef/artifacts
# runID: 4734d20d861e4c009dc8864d6e556bef
# Testing for 32011-37010:37011-37070
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2878
# 1.0    2122
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 73.68, 'class_1': 54.55}
# {'class_0': 73.68, 'class_1': 54.55}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/24e7b0914a9148b7b7446172bcb751cf/artifacts
# runID: 24e7b0914a9148b7b7446172bcb751cf
# Testing for 31951-36950:36951-37010
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2861
# 1.0    2139
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 78.26, 'class_1': 21.43}
# {'class_0': 78.26, 'class_1': 21.43}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/3962c580311641ecbf33a00ea4a15072/artifacts
# runID: 3962c580311641ecbf33a00ea4a15072
# Testing for 31891-36890:36891-36950
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2864
# 1.0    2136
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 78.12, 'class_1': 35.71}
# {'class_0': 78.12, 'class_1': 35.71}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/f911cacd58a544d9b38d53182b8b82be/artifacts
# runID: f911cacd58a544d9b38d53182b8b82be
# Testing for 31831-36830:36831-36890
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2884
# 1.0    2116
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 67.57, 'class_1': 13.04}
# {'class_0': 67.57, 'class_1': 13.04}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/cb1c0ccbf45d482ca01bbb55389ad910/artifacts
# runID: cb1c0ccbf45d482ca01bbb55389ad910
# Testing for 31771-36770:36771-36830
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2892
# 1.0    2108
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 70.45, 'class_1': 87.5}
# {'class_0': 70.45, 'class_1': 87.5}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/ea67bcd135164d95ac7deb83add8b717/artifacts
# runID: ea67bcd135164d95ac7deb83add8b717
# Testing for 31711-36710:36711-36770
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2900
# 1.0    2100
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 3.23, 'class_1': 100.0}
# {'class_0': 3.23, 'class_1': 100.0}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/a9caf1cf201b485399659557efc15fff/artifacts
# runID: a9caf1cf201b485399659557efc15fff
# Testing for 31651-36650:36651-36710
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2919
# 1.0    2081
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 18.18, 'class_1': 52.63}
# {'class_0': 18.18, 'class_1': 52.63}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/c8e603c97c3647909dbef42627c47f56/artifacts
# runID: c8e603c97c3647909dbef42627c47f56
# Testing for 31591-36590:36591-36650
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2916
# 1.0    2084
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 94.74, 'class_1': 9.09}
# {'class_0': 94.74, 'class_1': 9.09}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/c9417f0f19144552b60eb6a5e0cad709/artifacts
# runID: c9417f0f19144552b60eb6a5e0cad709
# Testing for 31531-36530:36531-36590
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2916
# 1.0    2084
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 82.5, 'class_1': 30.0}
# {'class_0': 82.5, 'class_1': 30.0}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/1e40ca3578124f48a3fd0a9ba47d2c25/artifacts
# runID: 1e40ca3578124f48a3fd0a9ba47d2c25
# Testing for 31471-36470:36471-36530
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2926
# 1.0    2074
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 100.0, 'class_1': 0.0}
# {'class_0': 100.0, 'class_1': 0.0}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/71e4e40ff1ad4e738b3679fc437526b7/artifacts
# runID: 71e4e40ff1ad4e738b3679fc437526b7
# Testing for 31411-36410:36411-36470
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2935
# 1.0    2065
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 54.55, 'class_1': 43.75}
# {'class_0': 54.55, 'class_1': 43.75}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/88f4d41b5e77439da180384f2b5aad2d/artifacts
# runID: 88f4d41b5e77439da180384f2b5aad2d
# Testing for 31351-36350:36351-36410
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2935
# 1.0    2065
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 8.82, 'class_1': 96.15}
# {'class_0': 8.82, 'class_1': 96.15}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/b12d488a1af24428bf490147a03ff96f/artifacts
# runID: b12d488a1af24428bf490147a03ff96f
# Testing for 31291-36290:36291-36350
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2951
# 1.0    2049
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 42.86, 'class_1': 69.23}
# {'class_0': 42.86, 'class_1': 69.23}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/374f5d6a5c4249e58ad798bc3ffa0709/artifacts
# runID: 374f5d6a5c4249e58ad798bc3ffa0709
# Testing for 31231-36230:36231-36290
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2934
# 1.0    2066
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 64.15, 'class_1': 71.43}
# {'class_0': 64.15, 'class_1': 71.43}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/2b806a4513f2489b9d810a0175600149/artifacts
# runID: 2b806a4513f2489b9d810a0175600149
# Testing for 31171-36170:36171-36230
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2913
# 1.0    2087
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 47.62, 'class_1': 66.67}
# {'class_0': 47.62, 'class_1': 66.67}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/e05a224f103745a199cb31bf6f5fe0cb/artifacts
# runID: e05a224f103745a199cb31bf6f5fe0cb
# Testing for 31111-36110:36111-36170
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2896
# 1.0    2104
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 13.89, 'class_1': 100.0}
# {'class_0': 13.89, 'class_1': 100.0}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/9ffc1f15594b4f6187a406360a06592f/artifacts
# runID: 9ffc1f15594b4f6187a406360a06592f
# Testing for 31051-36050:36051-36110
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2878
# 1.0    2122
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 52.08, 'class_1': 50.0}
# {'class_0': 52.08, 'class_1': 50.0}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/5e66a46691ec4a5a90008f08935cbe9f/artifacts
# runID: 5e66a46691ec4a5a90008f08935cbe9f
# Testing for 30991-35990:35991-36050
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2885
# 1.0    2115
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 91.49, 'class_1': 30.77}
# {'class_0': 91.49, 'class_1': 30.77}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/f78e0210a3364c0e8b6597a6c0cb2526/artifacts
# runID: f78e0210a3364c0e8b6597a6c0cb2526
# Testing for 30931-35930:35931-35990
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2882
# 1.0    2118
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 48.98, 'class_1': 72.73}
# {'class_0': 48.98, 'class_1': 72.73}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/578cdca62b7e4df594cfc1feb0f4f636/artifacts
# runID: 578cdca62b7e4df594cfc1feb0f4f636
# Testing for 30871-35870:35871-35930
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2903
# 1.0    2097
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 13.33, 'class_1': 86.67}
# {'class_0': 13.33, 'class_1': 86.67}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/d323fecd64e8463eb0098b7f1c78ae99/artifacts
# runID: d323fecd64e8463eb0098b7f1c78ae99
# Testing for 30811-35810:35811-35870
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2873
# 1.0    2127
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 100.0, 'class_1': 30.0}
# {'class_0': 100.0, 'class_1': 30.0}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/37e49e0c77a547c1880683b9d4d81065/artifacts
# runID: 37e49e0c77a547c1880683b9d4d81065
# Testing for 30751-35750:35751-35810
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2875
# 1.0    2125
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 97.37, 'class_1': 9.09}
# {'class_0': 97.37, 'class_1': 9.09}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/500a41b15bff4023bbc993a5254429c6/artifacts
# runID: 500a41b15bff4023bbc993a5254429c6
# Testing for 30691-35690:35691-35750
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2857
# 1.0    2143
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 76.0, 'class_1': 50.0}
# {'class_0': 76.0, 'class_1': 50.0}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/b01f6d22acd24b6f8f21d6bbc3f8e15b/artifacts
# runID: b01f6d22acd24b6f8f21d6bbc3f8e15b
# Testing for 30631-35630:35631-35690
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2855
# 1.0    2145
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 74.36, 'class_1': 14.29}
# {'class_0': 74.36, 'class_1': 14.29}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/7d39c7d25c80418e9dd8ee9b8ed76305/artifacts
# runID: 7d39c7d25c80418e9dd8ee9b8ed76305
# Testing for 30571-35570:35571-35630
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2859
# 1.0    2141
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 60.0, 'class_1': 73.33}
# {'class_0': 60.0, 'class_1': 73.33}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/35ed1bc7b035464b9f476d270f783b1c/artifacts
# runID: 35ed1bc7b035464b9f476d270f783b1c
# Testing for 30511-35510:35511-35570
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2869
# 1.0    2131
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 47.83, 'class_1': 67.57}
# {'class_0': 47.83, 'class_1': 67.57}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/b5bbf1eb837c4dbca6397b2c93449d87/artifacts
# runID: b5bbf1eb837c4dbca6397b2c93449d87
# Testing for 30451-35450:35451-35510
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2840
# 1.0    2160
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 68.75, 'class_1': 83.33}
# {'class_0': 68.75, 'class_1': 83.33}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/23b89cb608334997bb20f0deabcafdc7/artifacts
# runID: 23b89cb608334997bb20f0deabcafdc7
# Testing for 30391-35390:35391-35450
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2824
# 1.0    2176
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 97.92, 'class_1': 8.33}
# {'class_0': 97.92, 'class_1': 8.33}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/f85d8cbc41a84bda939914698ba196e0/artifacts
# runID: f85d8cbc41a84bda939914698ba196e0
# Testing for 30331-35330:35331-35390
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2781
# 1.0    2219
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 83.05, 'class_1': 0.0}
# {'class_0': 83.05, 'class_1': 0.0}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/4c4ccc06f0ea4c60bc58d286e4c03600/artifacts
# runID: 4c4ccc06f0ea4c60bc58d286e4c03600
# Testing for 30271-35270:35271-35330
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2772
# 1.0    2228
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 100.0, 'class_1': 25.0}
# {'class_0': 100.0, 'class_1': 25.0}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/232785fb6a32448a9649a7606a94375e/artifacts
# runID: 232785fb6a32448a9649a7606a94375e
# Testing for 30211-35210:35211-35270
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2755
# 1.0    2245
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 100.0, 'class_1': 0.0}
# {'class_0': 100.0, 'class_1': 0.0}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/b32a8e7a9c7a40a7a23fdb4c91e8dba1/artifacts
# runID: b32a8e7a9c7a40a7a23fdb4c91e8dba1
# Testing for 30151-35150:35151-35210
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2752
# ...
#  Running Model...
# Target variable is:  entry_type
# 0.0    2813
# 1.0    2187
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 100.0, 'class_1': 5.56}
# {'class_0': 100.0, 'class_1': 5.56}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/1169210e68a84301b8ecfa20245ec233/artifacts
# runID: 1169210e68a84301b8ecfa20245ec233
# Testing for 29491-34490:34491-34550
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2812
# 1.0    2188
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 80.0, 'class_1': 0.0}
# {'class_0': 80.0, 'class_1': 0.0}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/f4a59a8e6bb34c69be0bf41116d34304/artifacts
# runID: f4a59a8e6bb34c69be0bf41116d34304
# Testing for 29431-34430:34431-34490
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2835
# 1.0    2165
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 53.33, 'class_1': 56.67}
# {'class_0': 53.33, 'class_1': 56.67}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/adbc00a45ba844258f28c8982cc5befe/artifacts
# runID: adbc00a45ba844258f28c8982cc5befe
# Testing for 29371-34370:34371-34430
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2851
# 1.0    2149
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 37.5, 'class_1': 86.11}
# {'class_0': 37.5, 'class_1': 86.11}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/8da71321c48d4f1c8a99bfb3b6650fa2/artifacts
# runID: 8da71321c48d4f1c8a99bfb3b6650fa2
# Testing for 29311-34310:34311-34370
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2869
# 1.0    2131
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 28.57, 'class_1': 65.22}
# {'class_0': 28.57, 'class_1': 65.22}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/1978cd7513624898987c933dce526b4c/artifacts
# runID: 1978cd7513624898987c933dce526b4c
# Testing for 29251-34250:34251-34310
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2863
# 1.0    2137
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 19.44, 'class_1': 83.33}
# {'class_0': 19.44, 'class_1': 83.33}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/183f8c43b05846718fef727777cab616/artifacts
# runID: 183f8c43b05846718fef727777cab616
# Testing for 29191-34190:34191-34250
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2888
# 1.0    2112
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 28.57, 'class_1': 92.31}
# {'class_0': 28.57, 'class_1': 92.31}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/ad620e41923042a2bb1bb633de7441ed/artifacts
# runID: ad620e41923042a2bb1bb633de7441ed
# Testing for 29131-34130:34131-34190
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2913
# 1.0    2087
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 46.15, 'class_1': 41.18}
# {'class_0': 46.15, 'class_1': 41.18}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/58db06ca63d94de386787d0623989cae/artifacts
# runID: 58db06ca63d94de386787d0623989cae
# Testing for 29071-34070:34071-34130
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2931
# 1.0    2069
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 51.72, 'class_1': 51.61}
# {'class_0': 51.72, 'class_1': 51.61}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/243c7e8ac5f44fb298f59fa76cb23c5c/artifacts
# runID: 243c7e8ac5f44fb298f59fa76cb23c5c
# Testing for 29011-34010:34011-34070
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2940
# 1.0    2060
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 68.0, 'class_1': 54.29}
# {'class_0': 68.0, 'class_1': 54.29}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/fd82242618594dd5aea7ff566ae34373/artifacts
# runID: fd82242618594dd5aea7ff566ae34373
# Testing for 28951-33950:33951-34010
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2945
# 1.0    2055
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 15.79, 'class_1': 95.45}
# {'class_0': 15.79, 'class_1': 95.45}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/2859ca475b3e4d24880171ed27da658b/artifacts
# runID: 2859ca475b3e4d24880171ed27da658b
# Testing for 28891-33890:33891-33950
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2938
# 1.0    2062
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 67.5, 'class_1': 65.0}
# {'class_0': 67.5, 'class_1': 65.0}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/ca89df33524f458798e800cf4cb8c695/artifacts
# runID: ca89df33524f458798e800cf4cb8c695
# Testing for 28831-33830:33831-33890
# Index(['datetime', 'Vol', 'ticker', 'entry_market', 'target', 'stop', 'SMA_15',
#        'SMA_60', 'entry_type_lag_15', 'return_1m', 'return_15m', 'return_30m',
#        'return_60m', 'Vol_sma_5', 'Vol_sma_60', 'Vol_std_5', 'Vol_std_60',
#        'month_sin', 'month_cos', 'hour_sin', 'hour_cos', 'minute_sin',
#        'minute_cos', 'entry_type_sma_2', 'entry_type_sma_6',
#        'entry_type_std_2', 'entry_type_std_6', 'entry_type_cv_2',
#        'risk_type_sma_2', 'risk_type_sma_6', 'risk_type_std_2',
#        'risk_type_std_6', 'risk_type_cv_2'],
#       dtype='object')
#  Running Model...
# Target variable is:  entry_type
# 0.0    2941
# 1.0    2059
# Name: entry_type, dtype: int64
# Cross validation on:
# Testing for  211-4969:4970-4999
# Testing for  181-4939:4940-4969
# Testing for  151-4909:4910-4939
# Testing for  121-4879:4880-4909
# {'class_0': 59.38, 'class_1': 71.43}
# {'class_0': 59.38, 'class_1': 71.43}
# Storing Model Results...
#  Additional Parameters
#  Logging metrics
#  Logging class accuracy
#  Logging model
#  Logging CV results matrix
#  Logging Feature Importance
#  Logging Features
# file:///D:/Tensor_Invest_Fund/EntryTargetRisk-Model/02_Strategy_Layer/ML_Models/mlruns/44/565af67ed07d4c3595189aeb09acb8fc/artifacts
# runID: 565af67ed07d4c3595189aeb09acb8fc

# %%
# # Model for Sep 22-2021
# logged_model = 'runs:/34776846208744728b0bb34eda7260e6/Risk-Profit Trading Classification'

# # Load model as a PyFuncModel.
# loaded_model = mlflow.pyfunc.load_model(logged_model)

# # Predict on a Pandas DataFrame.
# Y_pred = loaded_model.predict(X_test)

# %%
Y_train = dfs[2]

# %%
X_train.shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e69384cdb520> in <module>
# ----> 1 X_train.shape[0]
#
# NameError: name 'X_train' is not defined

# %%
df.groupby(['Date'])['entry_type'].value_counts()
# Out:
# Date        entry_type
# 2021-06-01  0.0           229
#             1.0            48
# 2021-06-02  0.0           313
#             1.0            78
# 2021-06-03  0.0           268
#                          ...
# 2021-10-12  1.0           145
# 2021-10-13  0.0           233
#             1.0           158
# 2021-10-14  0.0           321
#             1.0            69
# Name: entry_type, Length: 192, dtype: int64

# %%
df[df['Date'] == '2021-09-22']['entry_type_fh_2'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\AlgoTrading\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'entry_type_fh_2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-f6042b39c152> in <module>
# ----> 1 df[df['Date'] == '2021-09-22']['entry_type_fh_2'].value_counts()
#
# ~\Anaconda3\envs\AlgoTrading\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\Anaconda3\envs\AlgoTrading\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'entry_type_fh_2'

# %%
df[df['Date'] == '2021-09-23']['entry_type_fh_2'].value_counts()
# Out:
# 0.0    268
# 1.0    106
# Name: entry_type_fh_2, dtype: int64

# %%
df[df['Date'] == '2021-09-24']['entry_type_fh_2'].value_counts()
# Out:
# 0.0    259
# 1.0    115
# Name: entry_type_fh_2, dtype: int64

# %%
# Importance = model.best_estimator_.feature_importances_

# df_importance = pd.DataFrame({'Variable': X_train.columns, 'Importance':Importance})

# df_importance.sort_values(by = ['Importance'], ascending = False, inplace = True)

# %%
# Y_test_pred = Y_test.copy(deep = True)
# Y_test_pred['pred'] = Y_pred
